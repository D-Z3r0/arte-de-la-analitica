# %% [markdown]
# # Actividad Evaluable 3: Mapas de calor y boxplots

# %% [markdown]
# ## Integrantes:
# **Rosa Vanessa Palacios Beltrán | A01652612**
#
# **Diego Reyna Reyes | A01657387**
#
# **José Roberto Garduño Cerecedo | A01656294**
#
# **Luis Angel Gonzalez Tapia| A01654625**
#
# **Samuel Sandoval Delgado | A01656191**
#
# **Daniel Rong Chen | A01656992**

# %% [markdown]
# En está actividad se realizará un análisis estadístico con los datos del archivo covid19_tweets.csv

# %% [markdown]
# ## 1. Cargar los datos usando tu lector de csv o con pandas.

# %%
#Importar las librerias para el analisis
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min
from sklearn import preprocessing
import seaborn as sns

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
dataframe = pd.read_csv(r"covid19_tweets.csv")
dataframe["date"] = pd.to_datetime(dataframe["date"])
dataframe["user_created"] = pd.to_datetime(dataframe["user_created"])
dataframe.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description        user_created  \
# 0  wednesday addams as a disney princess keepin i... 2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth... 2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re... 2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ... 2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf... 2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %% [markdown]
# Veamos la información básica sobre el macro de datos de los Tweets de COVID19

# %%
dataframe.dtypes
# Out:
# user_name                   object
# user_location               object
# user_description            object
# user_created        datetime64[ns]
# user_followers               int64
# user_friends                 int64
# user_favourites              int64
# user_verified                 bool
# date                datetime64[ns]
# text                        object
# hashtags                    object
# source                      object
# is_retweet                    bool
# dtype: object

# %%
dataframe.describe().transpose()
# Out:
#                    count           mean            std  min    25%     50%  \
# user_followers   74436.0  105951.312913  822289.985493  0.0  166.0   960.0
# user_friends     74436.0    2154.721170    9365.587474  0.0  153.0   552.0
# user_favourites  74436.0   15297.472030   46689.714291  0.0  220.0  1927.0
#
#                       75%         max
# user_followers    5148.00  13892841.0
# user_friends      1780.25    497363.0
# user_favourites  10148.00   2047197.0

# %% [markdown]
# # 2. Analisis de las variables

# %% [markdown]
# En esta sección analizaremos los datos y sacaremos algunas conclusiones basadas en el análisis.

# %% [markdown]
# Total de hashtags usados en los Tweets

# %%
dataframe['hashtags'].value_counts().head(10).plot.bar(
    figsize=(14, 7), fontsize=16, color='lightcoral'
)
plt.gca().set_title('Hastags Used in Tweets', fontsize=20)
plt.gca().set_xticklabels(plt.gca().get_xticklabels(), rotation=45, ha='right', fontsize=16)
pass

# %% [markdown]
# ## Diagrama de cajas y bigotes

# %%
sb.boxplot(dataframe, showfliers = False)
# Out:
# <Axes: >

# %%
sb.pairplot(dataframe.dropna(), hue='user_verified',size=4,vars=["user_followers","user_friends","user_favourites"],kind='scatter')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sb.pairplot(dataframe.dropna(),size=4,vars=["date","user_followers","user_friends"],kind='scatter',hue='user_verified')
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Histogramas

# %%
dataframe.hist()
plt.show()

# %% [markdown]
# ## Mapas de calor

# %%
data = dataframe.drop(columns='is_retweet') #Se eliminio la columna de is_retweets porque no trae ninguna información para analizar
colormap = plt.cm.viridis
plt.figure(figsize=(10,10))
plt.title("Correlaciones", y=1, size=15)
sb.heatmap(data.corr(), linewidths=0.1, vmax=1.0, square=True,
           cmap=colormap, linecolor="white",annot=True);

# %%
dataframe.columns
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize = (13,5))
plt.xlabel("Location", fontsize = 14)
plt.ylabel("NO. Tweets", fontsize = 14)
top_ct[0:5].plot(kind='pie', title= "Los lugares que más postearon durante el COVID-19")
# Out:
# <Axes: title={'center': 'Los lugares que más postearon durante el COVID-19'}, xlabel='Location', ylabel='user_location'>

# %% [markdown]
# # Conclusiones Rosa Vanessa Palacios Beltran A01652612
#
# **1. ¿Hay alguna variable que no aporta información?**
# is_retweet es la unica variable a mi consideración que no aporta nada por la falta de datos, pero creo que sera bueno porque podríamos ver los contexto que comparte las personas.
#
# **2. Si tuvieras que eliminar variables, ¿Cuáles quitarías y por qué?**
# Creo que cada variable se le puede tomar valor depende del objetivo o el proposito, pero mi respuesta anterior la variable is_retweet sería la unica que quitaría por la falta de información pero en caso de que hubiera o tenga información sería importante considerarla para un analisis por la importancia pues los retweets también pueden ayudarnos a identificar patrones y tendencias en el comportamiento de los usuarios en las redes sociales, así como la popularidad y la influencia de un tweet o usuario en particular.
#
# **3. ¿Existen variables que tengan datos extraños?**
# user_location y user_created ambas columnas tienen datos extraños por ejemplo para user_created marca que hay cuentas creadas desde 1970 y Twitter fue creado en el 2006, y para user_location hay lugares que no existen. Pero no por ser extraños signifique que no sirven o que no nos puedan ayudar a detectar conportamientos.
#
# **4. Si comparas las variables, ¿todas están en rangos similares?**
# Las variables en su mayoria son de tipo object, las variables de tipo int el rango no es tan diferente.
#
# **5. ¿Crees que esto afecte el análisis de los datos?**
# Si, al tener la variables con rangos similares puede afectar y hacer comparaciones inapropiadas y obtener resultados engañosos, sesgos en la visualización con rangos diferentes es posible ver valores destacados.
#
# **6. ¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos?**
# Si se pueden encontrar grupos por ejemplo gracias a los diagramas de puede visualizar que user_friends y user_followers son cuentas que si estan verificadas mientras que user_followers y user_friends son cuentas no verificas

# %% [markdown]
# # Conclusiones de Diego Reyna Reyes A01657387
# ## ¿Hay alguna variable que no aporta información?
#
# La variable is_retweet no da información, ya que no muestra el número total de retweets que tiene una publicación, por lo que no nos muestra  el engagement de los tweets.
# ## Si tuvieras que eliminar variables, ¿Cuáles quitarías y por qué?
#
# La variable is_retweet, ya que no aporta información, y el nombre de usuario, ya que no es de reelevancia para hacer un análisis de los tweets en conjunto, pero si se buscara hacer un perfil de las personas con ideas similares, si sería útil.
# ## ¿Existen variables que tengan datos extraños?
#
# La variable user_location trae lugares no válidos, al igual que la variable user_created, que nos genera fechas de creación que pasaron antes de la creación de la plataforma.
# ## Si comparas las variables, ¿todas están en rangos similares?
#
# Las variables numéricas están en rangos similares, pero si se comparan con las variables booleanas, estas estan en un rango menor [0-1], mientras que las fechas están en un rango mayor ya que se trata de una fecha.
# ## ¿Crees que esto afecte el análisis de los datos?
#
# Si, ya que si se hace un análisis de centroides (kmeans) las variables con un rango mayor, dominarán sobre aquellas de un rango menor, a menos que se normalicen todas las variables.
# ## ¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos?
#
# La mayoría de los usuarios cuentan con un número pequeño de seguidores, al igual que no están verificados. Igualmente se denota un correlación entre el número de user_friends y de user_favourites, ya que la mayoría de los usuarios cuentan con un valor pequeño en estas variables. Si se busca agrupar en grupos mas precisos, es necesario hacer un análisis de texto de las descripciones y del contenido de los tweets

# %% [markdown]
# **SAMUEL SANDOVAL DELGADO**
#
# ¿Hay alguna variable que no aporta información?
# Si tuvieras que eliminar variables, ¿Cuáles quitarías y por qué?
#
# Los retuits (is_retweet) porque es una dato que muestra la cantidad de retuits que hay en general, pero no es sobre un tuit en específico. Por lo que es un dato bastante ambiguo; pero seria bastante útil si es que esta variable reflejara sobre una publicacion de un usarion en especifico.
#
# ¿Existen variables que tengan datos extraños?
# Principalmente las de nombre de usuario, ya que muchas tienen simbolos o mini imagenes.
#
# Si comparas las variables, ¿todas están en rangos similares?
# solamente las variables de tipo entero, ya que las demas como las fechas y las variables tipo string como descripcion del usuario son bastante distintas
#
# ¿Crees que esto afecte el análisis de los datos?
# Probablemente ya que podria tomar absolutos el programa y no tomar en cuenta diferentes tipos de usuario.
#
# ¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos?
# Mediante el mapa de calor se puede ver que los usuarios con pocos tweets con cuenta sin verificar y pocos followers son un grupo que puede haber en los datos. Tambien otro es el grupo users_friends y users favourites

# %% [markdown]
# # **Conclusión de Luis Angel Gonzales Tapia**
# **¿Hay alguna variable que no aporta información?**
#
# La variable que no aporta información son los Re-tweet
#
# **Si tuvieras que eliminar variables, ¿Cuáles quitarías y por qué?**
#
# La variable de Re-tweets, dado que cuando se plantearon las tablas nos percatamos que no hay una diferencia por lo tanto esta información termina siendo insuficiente para poder contrastarla con otro tipo de información.
#
# **¿Existen variables que tengan datos extraños?**
#
# Las variables que tienen datos extraños son los user_descrption, dado a que estos tienden a tener mucha información atípica que no aporta mucho, mientras unos nos ofrecen información respecto origen y que ejercen, tenemos personas que nos aportan información muy desordenada.
#
# **Si comparas las variables, ¿todas están en rangos similares?**
#
# No todas las variables tienen rango similares, tenemos datos que contrastan mucho como lo podemos ver en la tabla de bigote que tenemos una gran cantidad de user_favorites y por otra parte tenemos una baja cantidad de user_friends, esto muestra que sus rangos no son similares. Donde si tenemos rangos similares son en la cantidad usre_follower y user_friends, podemos ver que la diferencia de correlación es muy poca, tienendo numero muy parecidos, esto reflejando que comparte la misma cantidad de followers y frieds van siendo lo mismo.
#
# **¿Crees que esto afecte el análisis de los datos?**
#
# Si, dado que la información diferente podría ayudarnos a ver como es que el mensaje pueda llegar a otros usuarios. Una cantidad diferente de followers puodría resultar en que unos tweets puedan ser mayor o menor dado a que los diferentes retweets puede ser diferentes.
#
# **¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos?**
#
# Los grupos que mas se parecen son los de user_friends y user favorites, tienen datos muy dispersos pero la mayoría estan concentrados, otro grupo es el de los países siendo India el que mas se repiten, en la tabla de pastel se puede ver que se repite mucho este patron.

# %% [markdown]
# ## Conclusión Daniel Rong A01656992
# ¿Hay alguna variable que no aporta información?
# Después de analizar los datos y las diversas variables de estos, existen diversas variables que el aporte de información es nula o casi nula, pues esta información no revela nada importante o relevante que deba ser interpretada. Un ejemplo de estas es la variable 'is_retweet', la cual indica si uno de los tweets fue retweeteado. Esta variable resulta irrelevante, ya que todos los valores son falsos y no se puede extraer información de esta. Por otra parte, otra variable que no aporte mucha información es 'user_friends', porque saber el número de amigos que tiene un usuario no es importante y no es un aspecto de relevancia que pueda proporcionar información a la hora de analizar los datos. De igual manera, la variable 'user_created' y 'user_location' también son variables que no aportan mucha información, puesto que la primera indica la fecha de creación del usuario y solo daría espacio para interpretar si fue una cuenta creada antes o durante la pandemia; en cuanto a la segunda variable, esta sí proporciona información relevante, ya que revela el lugar desde donde fue publicado el tweet, sin embargo los datos no son consistentes, pues hay entradas de lugar que no son lugares reales o no hay. Por último, la variable 'user_name' no aporta mucha información, debido a que todos los valores son únicos y están establecidos por los usuarios, a diferencia de 'user_description', que a pesar de tener valors únicos también, se puede obtener rasgos de personalidad a partir de estos.
#
# Si tuvieras que eliminar variables, ¿Cuáles quitarías y por qué?
# De esta manera, las variables que pueden ser eliminadas o sustituidas serían las que casi no aportan información. En este caso serían las variables: 'is_retweet', 'user_location', 'user_created', 'user_friends','user_name' y algún otro. En el caso de  'user_friends' no afecta mucho su borrado, ya que se tiene a la variable 'user_followers' que aporta más información y da espacio para más interpretaciones. Por otro lado, 'user_location' y 'user_name' son variables irrelevantes, pues los datos de estos son únicos o son incosistentes. De igual forma, 'is_retweet' y 'user_created' no indican mucha información que derive a interpretaciones.
#
# ¿Existen variables que tengan datos extraños?
# Las variables con datos extraños serían 'user_location' y 'user_name', porque en la primera hay valores de lugares que no existen, no son lugares o simplemente no hay valores, mientras que en la otra variable hay valores que no son completamente entradas de texto.
#
# Si comparas las variables, ¿todas están en rangos similares?
# Comparando y contanto las variables se puede observar que hay no todas las variables contienen la misma cantidad de datos, por lo que los rangos de datos son distintos. Por ejemplo, hay variables como 'user_location' o 'hashtags' que tienen menor cantidad de datos, porque hay tweets que tienen estas variables vacías. En cuanto a las demás variables, la cantidad de datos es similar. pero con base en las gráficas, hay variables cuyos rangos de datos no son similares. Un ejemplo de estas sería que en la gráfica de cajas y bigotes se puede observar que los rangos son diferentes para variable.
#
# ¿Crees que esto afecte el análisis de los datos?
# Que no todos lo datos estén en el mismo rango puede afectar el análisis de datos, ya que el hecho de que haya datos con variables vacías hace que a la hora de graficar haya espacios vacíos que afecten las interpretaciones. Sin embargo, pensando en los valores de las variables, que hayan distintos rangos puede aportar información, en este caso, información acerca de los seguidores y los likes.
#
# ¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos?
# Con base en las gráficas, se puede observar que hay variables que de cierta manera están agrupadas como 'user_followers' y 'user_friends', ya que los valores que contienen estas 2 variables son bastentes similares e suelen tener la misma tendencia. Por otra parte, analizando las correlaciones, puede ser que las variables 'user_followers' y 'user_verified' tienen una relación o dependencia, pues se puede interpretar que los usuarios verificados tienden a tener más seguidores.

# %% [markdown]
# # Conclusiones José Roberto Garduño Cerecedo A01656294
#
# **¿Hay alguna variable que no aporta información?**
# la variable "is_retweet" no aporta informacion para analizar debido a la falta de datos.
#
# **Si tuvieras que eliminar variables, ¿Cuáles quitarías y por qué?**
# Continuando con la idea de la respuesta anterior, la variable is_retweet se podría eliminar ya que se trata de una variable booleana la cual no cambia, se mantiene en false. Por lo tanto, para este contexto no tiene la suficiente importancia para ser analizada; sin embargo, esto cambiaría si el valor de la variable cambiara en diferentes registros, ya que se podría observar y comparar cuantos de los tweets registrados han sido retweeteados y determinar el impacto del mismo.
#
# **¿Existen variables que tengan datos extraños?**
# En este caso, la varialbe "user_location" cuenta con registros los cuales causan controversia ya que por ejemplo, en el primer registro se tiene como lugar "astroworld" el cual no tiene sentido ya que no es un lugar que existe.
#
# **Si comparas las variables, ¿todas están en rangos similares?**
# Las variables que son numericas se puede decir que se encuentran en rangos similares, sin embargo también existen variables booleanas que tienen un rango de 0-1 y otras de tipo fecha.
#
# **¿Crees que esto afecte el análisis de los datos?**
# Sí, ya que a la hora de comparar las variables con respecto a su rango, las variables que cuenten con un rango mayor afectaran al análisis de aquellas que tienen un rango menor. De esta manera, se complica el obtener una conclusión acertada sobre los datos a analizar.
#
# **¿Puedes encontrar grupos que se parezcan? ¿Qué grupos son estos?**
# Tomando en cuenta los pairplots obtenidos, se puede decir que los grupos de "user_favourites" y "user_friends" son similares ya que sus valores prevalecen por debajo del valor de 100,000.
